# %%
from ultralytics import YOLO
import cv2 
from matplotlib import pyplot as plt
import torch
import numpy as np

# %%
imgpath=r"C:\Users\Mahdi\Desktop\New folder\project-9-at-2025-07-19-18-02-ca770e50 (1)\images\0dcc40e6-frame00901.png".replace('\\','/')

# %%
model = YOLO("yolo11s.pt" , task = "detect", verbose = True,)  # load a pretrained model (recommended for training)

# %%
results = model.train(data=r"data\project-9-at-2025-07-19-18-02-ca770e50 (1)\config.yaml".replace('\\','/'), epochs=100 , device=-1)
# Out:
# New https://pypi.org/project/ultralytics/8.3.168 available  Update with 'pip install -U ultralytics'
# Searching for 1 idle GPUs with free memory >= 20.0% and free utilization >= 0.0%...
# Selected idle CUDA devices [0]
# Ultralytics 8.3.166  Python-3.12.11 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
model.save("trained models/yolo11s_trained.pt")

# %%
# load model
model = YOLO("trained models/yolo11s_trained.pt" , task = "detect", verbose = True,)

# %%
# results = model([imgpath,
#                 ])  # return a list of Results objects

# %%
#img = cv2.imread(imgpath)

# %%
# img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#plt.imshow(img_rgb)
#plt.show()

# %%
# for (x, y, w, h) in results[0].boxes:
#     cv2.rectangle(img_rgb, (x, y), (x + w, y + h), (0, 255, 0), 5)

# %%
# plt.imshow(img_rgb)
# plt.show()

# %%
#results[0]

# %%
video_path=r'data\Project_20250719_085238_1.mp4'.replace('\\','/')
g_results = model(video_path,stream = True,)  # return a list of Results objects

# %%
# # View results
# for result in results:
#     boxes = result.boxes  # Boxes object for bounding box outputs
#     result.show()
#     #result.show()  # display to screen
#     #if cv2.waitKey(25) & 0xFF == ord('q'):
#     #    break

# %%
output_video_path='output_videos/outputvideo.mp4'
# Open the video file
cap = cv2.VideoCapture(video_path)

# Get video properties for output video writer
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for .mp4


 # Create VideoWriter object
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform inference on the frame
    results = model(frame) # Adjust confidence threshold

    # Annotate the frame with predictions
    annotated_frame = results[0].plot()

    # Display the annotated frame
    #cv2.imshow("YOLO Predictions", annotated_frame)
    #if cv2.waitKey(1) & 0xFF == ord('q'):
    #    break
    
    # Write the annotated frame to the output video
    out.write(annotated_frame)
    # Exit on 'q' key press
    

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 34 chickens, 42.5ms
# Speed: 2.9ms preprocess, 42.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 chickens, 24.8ms
# Speed: 2.2ms preprocess, 24.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 chickens, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 chickens, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 chickens, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 chickens, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 chickens, 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 chickens, 8.4ms
# ...

# %%
for result in g_results:
    result.show()
# Out:
# video 1/1 (frame 2/9957) C:\Users\Mahdi\Documents\GitHub\poultry-chicken_project\data\Project_20250719_085238_1.mp4: 384x640 35 chickens, 6.9ms
# video 1/1 (frame 3/9957) C:\Users\Mahdi\Documents\GitHub\poultry-chicken_project\data\Project_20250719_085238_1.mp4: 384x640 34 chickens, 6.6ms
# video 1/1 (frame 4/9957) C:\Users\Mahdi\Documents\GitHub\poultry-chicken_project\data\Project_20250719_085238_1.mp4: 384x640 34 chickens, 6.1ms
# video 1/1 (frame 5/9957) C:\Users\Mahdi\Documents\GitHub\poultry-chicken_project\data\Project_20250719_085238_1.mp4: 384x640 35 chickens, 5.7ms
# video 1/1 (frame 6/9957) C:\Users\Mahdi\Documents\GitHub\poultry-chicken_project\data\Project_20250719_085238_1.mp4: 384x640 35 chickens, 12.7ms
# video 1/1 (frame 7/9957) C:\Users\Mahdi\Documents\GitHub\poultry-chicken_project\data\Project_20250719_085238_1.mp4: 384x640 36 chickens, 5.8ms
# ...

# %%
print(cv2.getBuildInformation())
# Out:
# General configuration for OpenCV 4.12.0 =====================================
#   Version control:               4.12.0
#
#   Platform:
#     Timestamp:                   2025-07-04T16:40:32Z
#     Host:                        Windows 10.0.26100 AMD64
#     CMake:                       3.24.2
#     CMake generator:             Visual Studio 17 2022
#     CMake build tool:            C:/Program Files/Microsoft Visual Studio/2022/Enterprise/MSBuild/Current/Bin/amd64/MSBuild.exe
#     MSVC:                        1944
#     Configuration:               Debug Release
#     Algorithm Hint:              ALGO_HINT_ACCURATE
#
#   CPU/HW features:
#     Baseline:                    SSE SSE2 SSE3
#       requested:                 SSE3
#     Dispatched code generation:  SSE4_1 SSE4_2 AVX FP16 AVX2 AVX512_SKX
#       SSE4_1 (17 files):         + SSSE3 SSE4_1
#       SSE4_2 (1 files):          + SSSE3 SSE4_1 POPCNT SSE4_2
#       AVX (9 files):             + SSSE3 SSE4_1 POPCNT SSE4_2 AVX
# ...
